# %%
# %matplotlib inline

# %%
import numpy as np
import time

import evaluator

# %% [markdown]
# ## Plot

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
def plot_seg(seg, border=False):
    unique, unique_inverse = np.unique(seg, return_inverse=True)
    N = len(unique)
    cmap = np.random.rand(N,3)
    if border:
        cmap[0,:] = 0
    cmap = matplotlib.colors.ListedColormap(cmap)
    plt.imshow(np.arange(N)[unique_inverse].reshape(seg.shape), cmap=cmap)

# %% [markdown]
# ## h5py

# %%
import h5py
import os

# %%
fpath = '~/Data_local/datasets/SNEMI3D/data/train_segb.h5'
fpath = os.path.expanduser(fpath)

with h5py.File(fpath, 'r') as f:
    seg = f['/main'][...]

# %%
z = 3
plt.figure(figsize=(10,10))
plot_seg(seg[z,:,:], border=True)
plt.show()

# %% [markdown]
# ## Evaluator

# %%
evaluator.create_border_mask(seg, seg, 3)

# %%
z = 3
plt.figure(figsize=(10,10))
plot_seg(seg[z,:,:], border=True)
plt.show()

# %%
fpath = '~/Data_local/datasets/SNEMI3D/data/train_segb3.h5'
fpath = os.path.expanduser(fpath)

with h5py.File(fpath, 'w') as f:
    f.create_dataset('/main', data=seg)
